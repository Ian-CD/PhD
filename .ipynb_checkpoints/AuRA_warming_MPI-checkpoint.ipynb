# %%
import xarray as xr
import pandas as pd
import numpy as np
import calendar as cld
import matplotlib.pyplot as plt
import matplotlib.colors
colors_land = plt.cm.terrain(np.linspace(0.25, 1, 256))
import proplot as pplt # New plot library (https://proplot.readthedocs.io/en/latest/)
pplt.rc['savefig.dpi'] = 300 # 1200 is too big! #https://proplot.readthedocs.io/en/latest/basics.html#Creating-figures
from scipy.stats import chi2
from numba import njit,prange
import matplotlib as mpl
mpl.rcParams['hatch.linewidth'] = 0.05  # previous pdf hatch linewidth
from matplotlib.dates import DateFormatter

# %%
normal_format = {'gridlinewidth':0.1, 'gridcolor':'gray8', 'gridalpha':0.5, 'coast':True,'borders':True ,'reso':'hi', 'labels':True, 'lonlines':2, 'latlines':2, 'abc':False, 'latlim':[44.,47.],'lonlim':[2.2,7.2]}
multiplot_format = {'gridlinewidth':0.1, 'gridcolor':'gray8', 'gridalpha':0.5, 'coast':True,'borders':True ,'reso':'hi', 'labels':False, 'lonlines':2, 'latlines':2, 'abc':False, 'latlim':[43.,48.5],'lonlim':[4.,16.]}

imin = 17 ; imax = -133
jmin = 36 ; jmax = -45
ds = xr.open_dataset('/bettik/beaumetj/MARout/MAR-EC-Earth3/MARgrid_EUe.nc')
lon = np.array(ds.LON[jmin:jmax,imin:imax])
lat = np.array(ds.LAT[jmin:jmax,imin:imax])
H = np.array(ds.SH[jmin:jmax,imin:imax])
nlat,nlon = 45, 51

# %%
f, ax = pplt.subplots(proj='cyl', axwidth=8)
m=ax.pcolormesh(lon, lat, H, levels=34,cmap=colors_land)
f.colorbar(m,label= 'm.asl')

ax.format(**normal_format,suptitle='MAR EC-Earth3 topography')
ax.format(ocean=True,oceancolor='royalblue',reso='hi', latlim=[40.,51.],lonlim=[0.,20.])
ax.plot([2.5,7.,7,2.5,2.5],[44.1,44.1,46.8,46.8,44.1],'--r')
# Out:
# (<matplotlib.lines.Line2D at 0x7f241e949910>,)

# %%
f, ax = pplt.subplots(proj='cyl', axwidth=9)
m=ax.pcolormesh(lon, lat, H, levels=34,cmap=colors_land)
f.colorbar(m,label= 'm.asl')

ax.format(**normal_format,suptitle='Alps region')
ax.format(ocean=True,oceancolor='royalblue',reso='hi')#, latlim=[40.,51.],lonlim=[0.,20.])

# %%
path_hist = '/bettik/beaumetj/MARout/MAR-MPI-ESM1-2-HR/HIST/daily/ICE.MPI-ESM_HIST.EUy.TTz.'
path_85 = '/bettik/beaumetj/MARout/MAR-MPI-ESM1-2-HR/SSP585/daily/ICE.MPI-ESM_SSP585.EUy.TTz.'

first_year = 2001
last_year = 2030

for year in list(range(first_year,last_year+1)):
    print(year,end=' ')
    if year<2015:
        path = path_hist
    else: path = path_85
    ds_T = xr.open_dataset(path+str(year)+'.nc')
    year_mean = ds_T.TTz[:,0,jmin:jmax,imin:imax].mean('time')
    
    if year> first_year:
        period_year_mean += year_mean
    else:
        period_year_mean = xr.DataArray.copy(year_mean)

period_year_mean /= (last_year-first_year+1)

print(period_year_mean.shape)
# Out:
# 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030

# %%
period_year_mean.mean('y').mean('x')
# Out:
# <xarray.DataArray 'TTz' ()>
# array(10.020383, dtype=float32)
# Coordinates:
#     ztqlev   float32 2.0

# %%
path_hist = '/bettik/beaumetj/MARout/MAR-MPI-ESM1-2-HR/HIST/daily/ICE.MPI-ESM_HIST.EUy.TTz.'
path_85 = '/bettik/beaumetj/MARout/MAR-MPI-ESM1-2-HR/SSP585/daily/ICE.MPI-ESM_SSP585.EUy.TTz.'

first_year = 2036
last_year = 2065

for year in list(range(first_year,last_year+1)):
    print(year,end=' ')
    if year<2015:
        path = path_hist
    else: path = path_85
    ds_T = xr.open_dataset(path+str(year)+'.nc')
    year_mean = ds_T.TTz[:,0,jmin:jmax,imin:imax].mean('time')
    
    if year> first_year:
        period_year_mean_36_65 += year_mean
    else:
        period_year_mean_36_65 = xr.DataArray.copy(year_mean)

period_year_mean_36_65 /= (last_year-first_year+1)

print(period_year_mean_36_65.shape)
# Out:
# 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045 2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059 2060 2061 2062 2063 2064 2065 (45, 51)

# %%
period_year_mean_36_65.mean('y').mean('x')
# Out:
# <xarray.DataArray 'TTz' ()>
# array(11.040543, dtype=float32)
# Coordinates:
#     ztqlev   float32 2.0

# %%
diff = period_year_mean_36_65 - period_year_mean

# %%
diff.mean('y').mean('x')
# Out:
# <xarray.DataArray 'TTz' ()>
# array(1.0201597, dtype=float32)
# Coordinates:
#     ztqlev   float32 2.0

# %%
diff
# Out:
# <xarray.DataArray 'TTz' (y: 45, x: 51)>
# array([[0.96628475, 0.9590893 , 0.95716095, ..., 1.1695709 , 1.1859312 ,
#         1.1751332 ],
#        [0.9783783 , 0.9804697 , 0.97121334, ..., 1.2093048 , 1.2170019 ,
#         1.2082586 ],
#        [0.98566055, 0.98554707, 0.9785843 , ..., 1.2277756 , 1.234839  ,
#         1.2389202 ],
#        ...,
#        [0.93621445, 0.92424583, 0.9321251 , ..., 1.0132046 , 1.0258303 ,
#         1.0246162 ],
#        [0.92957973, 0.92142963, 0.9202213 , ..., 1.0131922 , 1.0106049 ,
#         1.0166302 ],
#        [0.92371655, 0.9241524 , 0.9272375 , ..., 1.002491  , 1.0019245 ,
#         1.0088978 ]], dtype=float32)
# Coordinates:
#   * x        (x) float32 -364.0 -357.0 -350.0 -343.0 ... -35.0 -28.0 -21.0 -14.0
#   * y        (y) float32 -56.0 -49.0 -42.0 -35.0 ... 231.0 238.0 245.0 252.0
#     ztqlev   float32 2.0

# %%
ds_T_2002 = xr.open_dataset('/bettik/beaumetj/MARout/MAR-MPI-ESM1-2-HR/HIST/daily/ICE.MPI-ESM_HIST.EUy.TTz.2002.nc')
year_mean_2002 = ds_T_2002.TTz[:,0,jmin:jmax,imin:imax].mean('time')

print(year_mean_2002.shape)
# Out:
# (45, 51)

# %%
year_mean_2002.mean('y').mean('x')
# Out:
# <xarray.DataArray 'TTz' ()>
# array(10.298987, dtype=float32)
# Coordinates:
#     ztqlev   float32 2.0

# %%
ds_T_2040 = xr.open_dataset('/bettik/beaumetj/MARout/MAR-MPI-ESM1-2-HR/SSP585/daily/ICE.MPI-ESM_SSP585.EUy.TTz.2040.nc')
year_mean_2040 = ds_T_2040.TTz[:,0,jmin:jmax,imin:imax].mean('time')

print(year_mean_2002.shape)
# Out:
# (45, 51)

# %%
year_mean_2040.mean('y').mean('x')
# Out:
# <xarray.DataArray 'TTz' ()>
# array(10.844764, dtype=float32)
# Coordinates:
#     ztqlev   float32 2.0

# %%
year_mean_2040.mean('y').mean('x') - year_mean_2002.mean('y').mean('x')
# Out:
# <xarray.DataArray 'TTz' ()>
# array(0.54577637, dtype=float32)
# Coordinates:
#     ztqlev   float32 2.0
