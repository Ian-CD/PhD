# %%
import xarray as xr
import pandas as pd
import numpy as np
import calendar as cld
import matplotlib.pyplot as plt
import matplotlib.colors
colors_land = plt.cm.terrain(np.linspace(0.25, 1, 256))
import proplot as pplt # New plot library (https://proplot.readthedocs.io/en/latest/)
pplt.rc['savefig.dpi'] = 300 # 1200 is too big! #https://proplot.readthedocs.io/en/latest/basics.html#Creating-figures
from scipy.stats import chi2
from numba import njit,prange
import matplotlib as mpl
mpl.rcParams['hatch.linewidth'] = 0.05  # previous pdf hatch linewidth
from matplotlib.dates import DateFormatter

# %%
ds = xr.open_dataset('/bettik/beaumetj/MARout/MAR-EC-Earth3/MARgrid_EUe.nc')

imin = 32 ; imax = -30
jmin = 20 ; jmax = -15
lon = np.array(ds.LON[jmin:jmax,imin:imax])
lat = np.array(ds.LAT[jmin:jmax,imin:imax])
H = np.array(ds.SH[jmin:jmax,imin:imax])
nlat,nlon = 91, 139

normal_format = {'gridlinewidth':0.1, 'gridcolor':'gray8', 'gridalpha':0.5, 'coast':True,'borders':True ,'reso':'hi', 'labels':True, 'lonlines':2, 'latlines':2, 'abc':False, 'latlim':[43.,48.5],'lonlim':[4.,16.]}
multiplot_format = {'gridlinewidth':0.1, 'gridcolor':'gray8', 'gridalpha':0.5, 'coast':True,'borders':True ,'reso':'hi', 'labels':False, 'lonlines':2, 'latlines':2, 'abc':False, 'latlim':[43.,48.5],'lonlim':[4.,16.]}

# %%
ds_MPIhist = xr.open_dataset('/bettik/castelli/data/MPI-ESM1-2-HR/MPI-ESM1-2-HR_historical_r1i1p1f1_gn_185001-201412.nc')
ds_MPI245 = xr.open_dataset('/bettik/castelli/data/MPI-ESM1-2-HR/MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_201501-210012.nc')
ds_MPI585 = xr.open_dataset('/bettik/castelli/data/MPI-ESM1-2-HR/MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_201501-210012.nc')

ds_MPI245
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1032, bnds: 2, lat: 192, lon: 384)
# Coordinates:
#   * time       (time) datetime64[ns] 2015-01-16T12:00:00 ... 2100-12-16T12:00:00
#   * lat        (lat) float64 -89.28 -88.36 -87.42 -86.49 ... 87.42 88.36 89.28
#   * lon        (lon) float64 0.0 0.9375 1.875 2.812 ... 356.2 357.2 358.1 359.1
#     height     float64 ...
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     tas        (time, lat, lon) float32 ...
# Attributes: (12/48)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            ScenarioMIP
#     branch_method:          standard
#     branch_time_in_child:   60265.0
#     branch_time_in_parent:  60265.0
#     contact:                cmip6-mpi-esm@dkrz.de
#     ...                     ...
#     variable_id:            tas
#     variant_label:          r1i1p1f1
#     license:                CMIP6 model data produced by DKRZ is licensed und...
#     cmor_version:           3.4.0
#     tracking_id:            hdl:21.14100/5d919613-fddc-429a-a6eb-e7b4cb90eaeb
#     NCO:                    netCDF Operators version 5.2.4 (Homepage = http:/...

# %%
ds_MPI245.tas
# Out:
# <xarray.DataArray 'tas' (time: 1032, lat: 192, lon: 384)>
# [76087296 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2015-01-16T12:00:00 ... 2100-12-16T12:00:00
#   * lat      (lat) float64 -89.28 -88.36 -87.42 -86.49 ... 87.42 88.36 89.28
#   * lon      (lon) float64 0.0 0.9375 1.875 2.812 ... 356.2 357.2 358.1 359.1
#     height   float64 ...
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Near-Surface Air Temperature
#     comment:        near-surface (usually, 2 meter) air temperature
#     units:          K
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella
#     history:        2019-07-15T20:20:00Z altered by CMOR: Treated scalar dime...

# %%
f, axs = pplt.subplots(proj='cyl', axwidth=8)

m=axs.pcolormesh(ds_MPI245.lon, ds_MPI245.lat, ds_MPI245.tas[0]-273.16, levels=10,cmap='Reds')
f.colorbar(m,label= 'tas')

#axs.format(**normal_format)
axs.format(ocean=True,oceancolor='lightgray',reso='hi')#, latlim=[40.,51.],lonlim=[0.,20.])
# Out:
# /home/castelli/.conda/envs/phd_v2/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:403: UserWarning: The `map_projection` keyword argument is deprecated, use `projection` to instantiate a GeoAxes instead.
#   warnings.warn("The `map_projection` keyword argument is "
# Figure(nrows=1, ncols=1, refwidth=8.0)

# %%
ds_MPI245_tas = ds_MPI245.tas-273.16

yrly_tas_MPI245 = ds_MPI245_tas.groupby("time.year").mean("time")
yrly_tas_MPI245
# Out:
# <xarray.DataArray 'tas' (year: 86, lat: 192, lon: 384)>
# array([[[-46.905376 , -46.885357 , -46.865498 , ..., -47.000103 ,
#          -46.9682   , -46.94037  ],
#         [-44.74115  , -44.808533 , -44.912537 , ..., -44.60069  ,
#          -44.638775 , -44.70225  ],
#         [-44.684345 , -44.788513 , -44.85785  , ..., -44.366962 ,
#          -44.482525 , -44.576275 ],
#         ...,
#         [-13.779714 , -13.776459 , -13.780202 , ..., -13.789968 ,
#          -13.776947 , -13.781667 ],
#         [-13.962169 , -13.964447 , -13.970795 , ..., -13.971446 ,
#          -13.976329 , -13.966075 ],
#         [-14.172943 , -14.171641 , -14.176686 , ..., -14.178314 ,
#          -14.178966 , -14.179128 ]],
#
#        [[-48.52124  , -48.486572 , -48.464924 , ..., -48.569904 ,
#          -48.589764 , -48.549397 ],
#         [-46.67993  , -46.77368  , -46.800537 , ..., -46.52954  ,
#          -46.589436 , -46.627686 ],
#         [-46.3243   , -46.45516  , -46.554768 , ..., -46.031006 ,
#          -46.14168  , -46.231037 ],
# ...
#         [-10.235314 , -10.223759 , -10.22148  , ..., -10.267541 ,
#          -10.255009 , -10.251102 ],
#         [-10.667606 , -10.667769 , -10.66484  , ..., -10.68258  ,
#          -10.674931 , -10.67135  ],
#         [-11.158656 , -11.15654  , -11.159144 , ..., -11.1554   ,
#          -11.150355 , -11.159307 ]],
#
#        [[-45.29828  , -45.30202  , -45.281353 , ..., -45.336853 ,
#          -45.321064 , -45.30821  ],
#         [-43.13747  , -43.207623 , -43.258404 , ..., -42.948017 ,
#          -43.00987  , -43.059673 ],
#         [-42.778748 , -42.86745  , -42.96283  , ..., -42.43858  ,
#          -42.57611  , -42.663837 ],
#         ...,
#         [ -9.4310875,  -9.425065 ,  -9.411068 , ...,  -9.477637 ,
#           -9.469987 ,  -9.452572 ],
#         [ -9.492774 ,  -9.497005 ,  -9.499935 , ...,  -9.510352 ,
#           -9.506934 ,  -9.504981 ],
#         [ -9.72959  ,  -9.732032 ,  -9.730729 , ...,  -9.733659 ,
#           -9.73545  ,  -9.726986 ]]], dtype=float32)
# Coordinates:
#   * lat      (lat) float64 -89.28 -88.36 -87.42 -86.49 ... 87.42 88.36 89.28
#   * lon      (lon) float64 0.0 0.9375 1.875 2.812 ... 356.2 357.2 358.1 359.1
#     height   float64 ...
#   * year     (year) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100

# %%
yrly_tas_MPI245_globalmean = yrly_tas_MPI245.mean("lat").mean("lon")
yrly_tas_MPI245_globalmean
# Out:
# <xarray.DataArray 'tas' (year: 86)>
# array([5.9718413, 5.9041862, 6.0065064, 6.3012643, 6.405733 , 6.1648784,
#        6.2686977, 6.318388 , 6.2513585, 6.3926787, 6.2435417, 6.185007 ,
#        6.3438096, 6.2572875, 6.6003203, 6.448809 , 6.4493237, 6.634398 ,
#        6.647405 , 6.732264 , 6.7144675, 6.561979 , 6.544353 , 6.516922 ,
#        6.349318 , 6.611717 , 6.731888 , 6.691622 , 6.4474273, 6.6153965,
#        6.6430907, 6.9076295, 6.9786553, 6.9779754, 7.0414543, 7.0539374,
#        7.1941376, 7.1754403, 7.0870876, 6.880016 , 6.8843646, 6.7757163,
#        7.0313377, 7.1605163, 7.2773805, 7.163133 , 6.924771 , 6.928125 ,
#        7.181969 , 7.1687865, 7.2020516, 7.4639564, 7.1829867, 7.1328826,
#        7.1975503, 7.504402 , 7.339293 , 7.5244484, 7.584537 , 7.7227864,
#        7.4210906, 7.574215 , 7.4096437, 7.363758 , 7.4434586, 7.612326 ,
#        7.658647 , 7.412472 , 7.489788 , 7.680453 , 7.5116754, 7.681132 ,
#        7.634023 , 7.579394 , 7.619558 , 7.6149654, 7.678641 , 7.6189284,
#        7.7901363, 7.7813773, 7.646387 , 7.7352805, 7.764511 , 7.550607 ,
#        7.5514045, 7.776651 ], dtype=float32)
# Coordinates:
#     height   float64 ...
#   * year     (year) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100

# %%
ds_MPI585_tas = ds_MPI585.tas-273.16

yrly_tas_MPI585_globalmean = ds_MPI585_tas.groupby("time.year").mean("time").mean("lat").mean("lon")
yrly_tas_MPI585_globalmean
# Out:
# <xarray.DataArray 'tas' (year: 86)>
# array([5.9951777, 6.156788 , 6.106439 , 6.2725234, 6.2980123, 6.308075 ,
#        6.174952 , 6.27428  , 6.177016 , 6.211531 , 6.136518 , 6.1571326,
#        6.343964 , 6.2156157, 6.3483787, 6.5056458, 6.6541677, 6.4621577,
#        6.4322534, 6.560112 , 6.8192673, 6.772261 , 6.7341824, 6.973208 ,
#        6.774923 , 6.8996716, 6.8027177, 6.8580985, 7.03723  , 6.9451637,
#        6.9055085, 6.85492  , 6.853962 , 7.2393513, 7.275759 , 7.208012 ,
#        7.3132553, 7.1253524, 7.351494 , 7.488262 , 7.37743  , 7.547558 ,
#        7.6423073, 7.6148515, 7.483227 , 7.663917 , 7.792141 , 7.712992 ,
#        7.9130425, 7.759353 , 7.9961867, 7.8437123, 7.935852 , 8.042461 ,
#        8.145765 , 8.359252 , 8.196922 , 8.311287 , 8.449689 , 8.525909 ,
#        8.395888 , 8.45578  , 8.583959 , 8.403108 , 8.711232 , 8.786216 ,
#        8.859988 , 8.908416 , 9.037056 , 8.934896 , 8.978955 , 8.862067 ,
#        9.149717 , 9.32399  , 9.309747 , 9.413539 , 9.592528 , 9.520671 ,
#        9.671836 , 9.650018 , 9.8150015, 9.786262 , 9.855869 , 9.906857 ,
#        9.912788 , 9.920246 ], dtype=float32)
# Coordinates:
#     height   float64 ...
#   * year     (year) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100

# %%
ds_MPIhist_tas = ds_MPIhist.tas-273.16

yrly_tas_MPIhist_globalmean = ds_MPIhist_tas.groupby("time.year").mean("time").mean("lat").mean("lon")
yrly_tas_MPIhist_globalmean
# Out:
# <xarray.DataArray 'tas' (year: 165)>
# array([4.8626065, 4.908033 , 5.041585 , 5.2371655, 4.7766585, 4.84234  ,
#        4.770241 , 4.770572 , 4.8137164, 4.681686 , 4.4719715, 4.8879538,
#        4.693115 , 4.632694 , 4.819937 , 4.776795 , 4.8284   , 4.905508 ,
#        5.029906 , 4.8571854, 4.919574 , 4.875375 , 4.6824813, 4.786988 ,
#        5.0091596, 4.9892225, 4.723089 , 4.756023 , 4.7717977, 4.6810465,
#        4.7449436, 4.9683547, 4.801285 , 5.075357 , 4.5154037, 4.47354  ,
#        4.519802 , 4.886657 , 5.0090404, 4.932841 , 4.9046984, 4.8555374,
#        4.8714643, 4.627282 , 4.843361 , 4.7841015, 4.7360024, 4.7681913,
#        4.6482577, 4.643652 , 4.7740846, 4.878306 , 5.0411115, 4.5287256,
#        4.6763926, 4.702983 , 4.5973525, 4.4871135, 4.856219 , 4.875183 ,
#        4.7396674, 4.777935 , 4.6799545, 4.8728895, 4.9733047, 5.1017847,
#        4.99507  , 5.073193 , 5.0476894, 4.940474 , 4.955347 , 5.002984 ,
#        5.0455756, 4.9771442, 5.119762 , 4.955206 , 5.200479 , 5.186622 ,
#        5.224687 , 5.120508 , 5.022702 , 5.106836 , 4.9550767, 5.069203 ,
#        5.278605 , 5.381023 , 5.441999 , 5.2532053, 5.1793847, 4.9844465,
#        5.256052 , 5.1757097, 5.1998158, 5.03454  , 5.194547 , 5.025722 ,
#        4.971455 , 5.352436 , 5.35745  , 5.204057 , 5.181662 , 5.222629 ,
#        5.1190786, 5.027344 , 5.02212  , 5.163932 , 5.0751033, 4.978167 ,
#        5.0369315, 5.214437 , 5.3821487, 5.3281903, 5.1435933, 5.096913 ,
#        5.102244 , 5.057819 , 5.1488357, 5.1026425, 5.081795 , 5.2191863,
#        5.2849   , 5.434061 , 5.251059 , 5.3474755, 5.128017 , 5.0450077,
#        5.329761 , 5.2839365, 5.3731556, 5.3897004, 5.4567795, 5.5672626,
#        5.4616547, 5.3100243, 5.42248  , 5.3959136, 5.42939  , 5.385554 ,
#        5.4256177, 5.4179397, 5.466104 , 5.4783635, 5.3310375, 5.222469 ,
#        5.308925 , 5.3857236, 5.3597617, 5.37454  , 5.372418 , 5.427109 ,
#        5.6942596, 5.66457  , 5.640194 , 5.690644 , 5.623628 , 5.761194 ,
#        5.8076687, 5.8522477, 6.1575255, 6.0434875, 5.9243264, 6.103395 ,
#        6.0154953, 5.9987235, 5.950361 ], dtype=float32)
# Coordinates:
#     height   float64 ...
#   * year     (year) int64 1850 1851 1852 1853 1854 ... 2010 2011 2012 2013 2014

# %%
del ds_MPIhist,ds_MPI245,ds_MPI585

# %%
DJF_tas_MPI245 = ds_MPI245_tas.sel(time=ds_MPI245_tas.time.dt.season=="DJF").groupby("time.year").mean("time").mean("lat").mean("lon")
MAM_tas_MPI245 = ds_MPI245_tas.sel(time=ds_MPI245_tas.time.dt.season=="MAM").groupby("time.year").mean("time").mean("lat").mean("lon")
JJA_tas_MPI245 = ds_MPI245_tas.sel(time=ds_MPI245_tas.time.dt.season=="JJA").groupby("time.year").mean("time").mean("lat").mean("lon")
SON_tas_MPI245 = ds_MPI245_tas.sel(time=ds_MPI245_tas.time.dt.season=="SON").groupby("time.year").mean("time").mean("lat").mean("lon")

allseas_tas_MPI245 = [DJF_tas_MPI245,MAM_tas_MPI245,JJA_tas_MPI245,SON_tas_MPI245]

DJF_tas_MPI585 = ds_MPI585_tas.sel(time=ds_MPI585_tas.time.dt.season=="DJF").groupby("time.year").mean("time").mean("lat").mean("lon")
MAM_tas_MPI585 = ds_MPI585_tas.sel(time=ds_MPI585_tas.time.dt.season=="MAM").groupby("time.year").mean("time").mean("lat").mean("lon")
JJA_tas_MPI585 = ds_MPI585_tas.sel(time=ds_MPI585_tas.time.dt.season=="JJA").groupby("time.year").mean("time").mean("lat").mean("lon")
SON_tas_MPI585 = ds_MPI585_tas.sel(time=ds_MPI585_tas.time.dt.season=="SON").groupby("time.year").mean("time").mean("lat").mean("lon")

allseas_tas_MPI585 = [DJF_tas_MPI585,MAM_tas_MPI585,JJA_tas_MPI585,SON_tas_MPI585]

DJF_tas_MPIhist = ds_MPIhist_tas.sel(time=ds_MPIhist_tas.time.dt.season=="DJF").groupby("time.year").mean("time").mean("lat").mean("lon")
MAM_tas_MPIhist = ds_MPIhist_tas.sel(time=ds_MPIhist_tas.time.dt.season=="MAM").groupby("time.year").mean("time").mean("lat").mean("lon")
JJA_tas_MPIhist = ds_MPIhist_tas.sel(time=ds_MPIhist_tas.time.dt.season=="JJA").groupby("time.year").mean("time").mean("lat").mean("lon")
SON_tas_MPIhist = ds_MPIhist_tas.sel(time=ds_MPIhist_tas.time.dt.season=="SON").groupby("time.year").mean("time").mean("lat").mean("lon")

allseas_tas_MPIhist = [DJF_tas_MPIhist,MAM_tas_MPIhist,JJA_tas_MPIhist,SON_tas_MPIhist]

DJF_tas_MPI245
# Out:
# <xarray.DataArray 'tas' (year: 86)>
# array([4.2408724, 4.1058517, 4.2662997, 4.4857874, 4.7152133, 4.387788 ,
#        4.5095882, 4.6468368, 4.5848737, 4.9886127, 4.802511 , 4.336535 ,
#        4.603949 , 4.4829006, 4.6695447, 5.077782 , 4.7880335, 5.027791 ,
#        4.96176  , 5.231639 , 5.1572247, 4.9687996, 4.7113123, 4.899865 ,
#        4.4155545, 4.715297 , 4.980514 , 4.873179 , 4.571013 , 4.8714056,
#        5.0278625, 5.028498 , 5.246858 , 5.3368745, 5.3761826, 5.5453115,
#        5.6646996, 5.632778 , 5.443851 , 5.234013 , 5.1643357, 5.049787 ,
#        5.495954 , 5.646608 , 5.6151204, 5.5266647, 5.1592484, 5.148166 ,
#        5.3999343, 5.5923533, 5.6020913, 5.7351723, 5.8359203, 5.6471596,
#        5.414004 , 6.003481 , 5.7323174, 5.898649 , 5.9797077, 6.256415 ,
#        5.990103 , 6.07591  , 5.836725 , 5.779364 , 6.0103793, 6.0349693,
#        6.1751723, 6.0517497, 6.00976  , 6.365931 , 5.8952446, 6.150557 ,
#        6.035221 , 5.951098 , 5.872763 , 6.1659718, 6.019674 , 6.226854 ,
#        6.321977 , 6.257076 , 6.2390513, 6.056026 , 6.198603 , 6.185761 ,
#        6.028605 , 6.272342 ], dtype=float32)
# Coordinates:
#     height   float64 ...
#   * year     (year) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100

# %%
plt.plot(np.arange(1850,2015,1),yrly_tas_MPIhist_globalmean)
plt.plot(np.arange(2015,2101,1),yrly_tas_MPI245_globalmean)
plt.plot(np.arange(2015,2101,1),yrly_tas_MPI585_globalmean)

# %%
#
#np.save('/bettik/castelli/data/MPI-ESM1-2-HR/yrly_tas_MPI_hist.npy', yrly_tas_MPIhist_globalmean)
#np.save('/bettik/castelli/data/MPI-ESM1-2-HR/yrly_tas_MPI_ssp245.npy', yrly_tas_MPI245_globalmean)
#np.save('/bettik/castelli/data/MPI-ESM1-2-HR/yrly_tas_MPI_ssp585.npy', yrly_tas_MPI585_globalmean)

# %%
f,axs = pplt.subplots(ncols=2,nrows=2)

seasons = ['DJF','MAM','JJA', 'SON']

for i in range(4):
    ax=axs[i]
    ax.plot(np.arange(1850,2015,1),allseas_tas_MPIhist[i])
    ax.plot(np.arange(2015,2101,1),allseas_tas_MPI245[i])
    ax.plot(np.arange(2015,2101,1),allseas_tas_MPI585[i])
    ax.format(title=seasons[i])
    ax.set_ylim((2.,12))
# Out:
# Figure(nrows=2, ncols=2, refwidth=2.5)

# %%
ds_MPI245_tas.groupby("time.season").mean("time").mean("lat").mean("lon")
# Out:
# <xarray.DataArray 'tas' (season: 4)>
# array([5.4037824, 9.118007 , 6.4415264, 7.1391816], dtype=float32)
# Coordinates:
#     height   float64 ...
#   * season   (season) object 'DJF' 'JJA' 'MAM' 'SON'

# %% [markdown]
# ## EC-Earth3

# %%
ds_ECEarth_hist = xr.open_dataset('/bettik/castelli/data/EC-Earth3/tas_Amon_EC-Earth3_hist_r25i1p1f1_gr_185001-201412.nc')
ds_ECEarth_245 = xr.open_dataset('/bettik/castelli/data/EC-Earth3/tas_Amon_EC-Earth3_ssp245_r25i1p1f1_gr_201501-210012.nc')

ds_ECEarth_245
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1032, bnds: 2, lat: 256, lon: 512)
# Coordinates:
#   * time       (time) datetime64[ns] 2015-01-16T12:00:00 ... 2100-12-16T12:00:00
#   * lat        (lat) float64 -89.46 -88.77 -88.07 -87.37 ... 88.07 88.77 89.46
#   * lon        (lon) float64 0.0 0.7031 1.406 2.109 ... 357.2 357.9 358.6 359.3
#     height     float64 ...
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     tas        (time, lat, lon) float32 ...
# Attributes: (12/48)
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               ScenarioMIP
#     branch_time:               0.0
#     contact:                   cmip6-data@ec-earth.org
#     creation_date:             2019-11-16T07:53:16Z
#     data_specs_version:        01.00.27
#     ...                        ...
#     parent_variant_label:      r1i1p1f1
#     branch_method:             standard
#     branch_time_in_parent:     60265.0
#     branch_time_in_child:      60265.0
#     nominal_resolution:        100 km
#     history:                   Thu Feb 13 00:35:20 2020: ncatted -O -a calend...

# %%
ds_ECEarth_hist
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1980, bnds: 2, lat: 256, lon: 512)
# Coordinates:
#   * time       (time) datetime64[ns] 1850-01-16T12:00:00 ... 2014-12-16T12:00:00
#   * lat        (lat) float64 -89.46 -88.77 -88.07 -87.37 ... 88.07 88.77 89.46
#   * lon        (lon) float64 0.0 0.7031 1.406 2.109 ... 357.2 357.9 358.6 359.3
#     height     float64 ...
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     tas        (time, lat, lon) float32 ...
# Attributes: (12/48)
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     branch_time:               0.0
#     contact:                   cmip6-data@ec-earth.org
#     creation_date:             2019-03-12T20:54:42Z
#     data_specs_version:        01.00.27
#     ...                        ...
#     parent_variant_label:      r1i1p1f1
#     branch_method:             standard
#     branch_time_in_parent:     288540.0
#     branch_time_in_child:      0.0
#     nominal_resolution:        100 km
#     history:                   Thu Feb 13 05:34:16 2020: ncatted -O -a calend...

# %%
ds_ECEarth_245_tas = ds_ECEarth_245.tas-273.16

del ds_ECEarth_245

yrly_tas_ECEarth_245 = ds_ECEarth_245_tas.groupby("time.year").mean("time")
yrly_tas_ECEarth_245_globalmean = yrly_tas_ECEarth_245.mean("lat").mean("lon")
yrly_tas_ECEarth_245_globalmean
# Out:
# <xarray.DataArray 'tas' (year: 86)>
# array([ 6.596375 ,  6.52731  ,  6.447194 ,  6.8378515,  6.6573496,
#         6.8660135,  6.854005 ,  6.7105246,  6.9154096,  6.838317 ,
#         6.97     ,  6.8130107,  6.8756986,  7.0428495,  7.1256638,
#         7.0897837,  7.3563595,  7.0780897,  7.076407 ,  7.464325 ,
#         7.4462805,  7.3016434,  7.4452114,  7.8772173,  7.6960726,
#         7.604437 ,  7.6410027,  7.4959016,  7.4950457,  7.5356255,
#         7.6044188,  7.9599195,  7.8416395,  8.135086 ,  7.960828 ,
#         8.089679 ,  8.322796 ,  7.9096737,  8.152658 ,  8.437657 ,
#         8.309715 ,  8.355686 ,  8.247602 ,  8.157255 ,  8.403301 ,
#         8.195856 ,  8.320375 ,  8.527606 ,  8.592076 ,  8.259379 ,
#         8.460436 ,  8.458131 ,  8.661131 ,  8.782381 ,  8.680718 ,
#         8.684273 ,  8.858346 ,  9.020479 ,  8.854603 ,  8.974724 ,
#         9.145515 ,  8.9690075,  8.981607 ,  8.983824 ,  9.10844  ,
#         8.948513 ,  9.084288 ,  9.185902 ,  9.270037 ,  9.2729645,
#         9.309053 ,  9.42103  ,  9.096506 ,  9.279591 ,  9.528179 ,
#         9.322027 ,  9.255894 ,  9.549114 ,  9.758712 ,  9.597994 ,
#         9.541897 ,  9.714392 ,  9.648517 ,  9.77964  , 10.116361 ,
#        10.0055895], dtype=float32)
# Coordinates:
#     height   float64 ...
#   * year     (year) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100

# %%
ds_ECEarth_hist_tas = ds_ECEarth_hist.tas-273.16

yrly_tas_ECEarth_hist = ds_ECEarth_hist_tas.groupby("time.year").mean("time")
yrly_tas_ECEarth_hist_globalmean = yrly_tas_ECEarth_hist.mean("lat").mean("lon")
yrly_tas_ECEarth_hist_globalmean
# Out:
# <xarray.DataArray 'tas' (year: 165)>
# array([5.1791697, 5.239054 , 5.4771175, 5.3663983, 5.3952007, 5.495762 ,
#        5.183076 , 5.080224 , 5.1201644, 5.173495 , 5.3026776, 5.3110795,
#        5.122559 , 4.9622107, 5.326105 , 5.2283163, 5.272686 , 5.151749 ,
#        5.26764  , 5.2974286, 5.2169404, 5.3087907, 5.056263 , 4.991927 ,
#        5.161392 , 5.051611 , 5.10847  , 5.0947165, 4.9810343, 4.9862823,
#        5.1073713, 5.097536 , 5.0604854, 4.791652 , 4.4576   , 4.5831194,
#        4.5602713, 4.536865 , 4.4603195, 4.4790516, 4.649396 , 4.6009045,
#        4.655747 , 4.5245357, 4.643914 , 4.8397675, 4.6367655, 4.748349 ,
#        4.8660355, 4.8609724, 5.007214 , 4.9274526, 4.7434454, 4.4908347,
#        4.5408688, 4.6694155, 4.6276493, 4.8672094, 4.796339 , 4.6753025,
#        4.697836 , 4.8150344, 4.5956182, 4.7120996, 4.602861 , 4.8446627,
#        4.9068537, 4.9444976, 5.1661587, 5.1289253, 4.9834046, 4.9653287,
#        5.300968 , 5.2134466, 5.373545 , 5.1590643, 5.276334 , 5.5577765,
#        5.470954 , 5.474791 , 5.619799 , 5.9388943, 5.661787 , 5.8257666,
#        5.6827736, 5.583727 , 5.607915 , 5.630131 , 5.7565465, 5.7141247,
#        5.8221006, 5.822135 , 5.929129 , 6.240937 , 5.93602  , 5.8511705,
#        6.063738 , 6.1024413, 5.967642 , 5.972714 , 6.154302 , 6.2538514,
#        6.0753226, 6.002304 , 6.260574 , 5.946667 , 6.094633 , 6.0411406,
#        5.8637524, 5.8806124, 5.9222713, 5.8703938, 5.8946066, 5.910591 ,
#        5.7580166, 5.533672 , 5.5412345, 5.528698 , 5.6937003, 5.85534  ,
#        5.9466076, 5.7981663, 5.9084253, 6.0228305, 5.8772764, 5.6840014,
#        5.8624268, 5.8635845, 5.9033136, 5.858945 , 6.019327 , 5.9401474,
#        6.0007253, 5.995396 , 5.7953343, 5.773847 , 5.999736 , 5.9500027,
#        6.0146093, 6.19745  , 6.200094 , 6.158121 , 5.71878  , 5.7966967,
#        5.8442316, 6.0845575, 6.135491 , 6.09772  , 6.328406 , 6.380297 ,
#        6.4221425, 6.2207413, 6.343215 , 6.3320494, 6.4468656, 6.362338 ,
#        6.2881074, 6.2899613, 6.5982285, 6.571005 , 6.5413146, 6.5345373,
#        6.4945564, 6.2880306, 6.715704 ], dtype=float32)
# Coordinates:
#     height   float64 ...
#   * year     (year) int64 1850 1851 1852 1853 1854 ... 2010 2011 2012 2013 2014

# %%
#np.save('/bettik/castelli/data/EC-Earth3/yrly_tas_ECEarth_hist.npy', yrly_tas_ECEarth_hist_globalmean)
#np.save('/bettik/castelli/data/EC-Earth3/yrly_tas_ECEarth_ssp245.npy', yrly_tas_ECEarth_245_globalmean)

# %%
yrly_tas_ECEarth_hist_globalmean = np.load('/bettik/castelli/data/EC-Earth3/yrly_tas_ECEarth_hist.npy')
yrly_tas_ECEarth_245_globalmean = np.load('/bettik/castelli/data/EC-Earth3/yrly_tas_ECEarth_ssp245.npy')

# %%
yrly_tas_MPIhist_globalmean = np.load('/bettik/castelli/data/MPI-ESM1-2-HR/yrly_tas_MPI_hist.npy')
yrly_tas_MPI245_globalmean = np.load('/bettik/castelli/data/MPI-ESM1-2-HR/yrly_tas_MPI_ssp245.npy')
yrly_tas_MPI585_globalmean = np.load('/bettik/castelli/data/MPI-ESM1-2-HR/yrly_tas_MPI_ssp585.npy')

# %%
plt.plot(np.arange(1850,2015,1),yrly_tas_MPIhist_globalmean)
plt.plot(np.arange(2015,2101,1),yrly_tas_MPI245_globalmean)
plt.plot(np.arange(2015,2101,1),yrly_tas_MPI585_globalmean)

plt.plot(np.arange(1850,2015,1),yrly_tas_ECEarth_hist_globalmean)
plt.plot(np.arange(2015,2101,1),yrly_tas_ECEarth_245_globalmean)
